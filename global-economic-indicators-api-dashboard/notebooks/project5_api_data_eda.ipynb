# %% [markdown]
# # Global Economic Indicators API EDA
#
# Beginner-friendly EDA for World Bank API data.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/world_bank_indicators_clean.csv')
df.head()

# %%
df.shape
df['short_name'].value_counts()

# %%
latest = pd.read_csv('../data/processed/world_bank_latest_indicators.csv')
latest[latest['indicator_code'] == 'NY.GDP.MKTP.CD'].sort_values('value', ascending=False)[['country_name', 'latest_year', 'value']]
